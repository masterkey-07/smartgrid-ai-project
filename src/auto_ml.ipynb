# %%
import numpy as np
import pandas as pd
from tpot import TPOTRegressor
from ucimlrepo import fetch_ucirepo 
from sklearn.model_selection import train_test_split

electrical_grid_stability_simulated_data = fetch_ucirepo(id=471).data

features = electrical_grid_stability_simulated_data.features 
targets = electrical_grid_stability_simulated_data.targets

data = pd.merge(features, targets, left_index=True, right_index=True, how='outer')
data.drop(columns=['stabf', 'p1', 'p2', 'p3', 'p4'], inplace=True)

# %%
data.head()
# Out:
#        tau1      tau2      tau3      tau4        g1        g2        g3  \
# 0  2.959060  3.079885  8.381025  9.780754  0.650456  0.859578  0.887445
# 1  9.304097  4.902524  3.047541  1.369357  0.413441  0.862414  0.562139
# 2  8.971707  8.848428  3.046479  1.214518  0.163041  0.766689  0.839444
# 3  0.716415  7.669600  4.486641  2.340563  0.446209  0.976744  0.929381
# 4  3.134112  7.608772  4.943759  9.857573  0.797110  0.455450  0.656947
#
#          g4      stab
# 0  0.958034  0.055347
# 1  0.781760 -0.005957
# 2  0.109853  0.003471
# 3  0.362718  0.028871
# 4  0.820923  0.049860

# %%
import os

# Get the number of CPUs
num_cpus = os.cpu_count()

print(f"Number of CPUs: {num_cpus}")
# Out:
# Number of CPUs: 12

# %%
auto_ml = TPOTRegressor(
        # generations=100,           # Allows for decent exploration with reasonable runtime
        # population_size=10,       # Balances diversity with computational efficiency
        offspring_size=None,      # Defaults to population_size if not set
        mutation_rate=0.9,        # High mutation rate encourages exploration
        crossover_rate=0.1,       # Low crossover rate emphasizes exploration over exploitation
        cv=5,                     # 5-fold cross-validation balances performance with runtime
        use_dask=True,
        n_jobs=num_cpus,
        early_stop=10,
        periodic_checkpoint_folder='./checkpoint',
        verbosity=2               # Provides updates on the progress
)

# %%
STAB_COLUMN_INDEX = list(data.columns).index('stab')

train, test = train_test_split(data, test_size=0.2)

y_train = train['stab'].values
x_train = train.drop(columns=['stab']).values

y_test = test['stab'].values
x_test = test.drop(columns=['stab']).values

auto_ml.fit(x_train, y_train)
    
pred = auto_ml.predict(x_test)
# Out:
#
# Generation 1 - Current best internal CV score: -7.234223320199358e-05
#
# Generation 2 - Current best internal CV score: -7.234223320199358e-05
#
# Generation 3 - Current best internal CV score: -7.234223320199358e-05
#
# Generation 4 - Current best internal CV score: -7.062653055136152e-05
#
# Generation 5 - Current best internal CV score: -6.637736165970412e-05
#
# Generation 6 - Current best internal CV score: -6.637736165970412e-05
#
# Generation 7 - Current best internal CV score: -6.572564800241687e-05
#
# Generation 8 - Current best internal CV score: -6.572564800241687e-05
#
# Generation 9 - Current best internal CV score: -6.297866010342273e-05
#
# Generation 10 - Current best internal CV score: -6.297866010342273e-05
#
# Generation 11 - Current best internal CV score: -5.848295855343494e-05
#
# Generation 12 - Current best internal CV score: -5.6870741755386635e-05
#
# Generation 13 - Current best internal CV score: -5.6870741755386635e-05
#
# Generation 14 - Current best internal CV score: -5.6870741755386635e-05
#
# Generation 15 - Current best internal CV score: -5.612486354282943e-05
#
# Generation 16 - Current best internal CV score: -5.612486354282943e-05
#
# Generation 17 - Current best internal CV score: -5.3789225179404836e-05
#
# Generation 18 - Current best internal CV score: -5.270507344976651e-05
#
# Generation 19 - Current best internal CV score: -5.0099385700467376e-05
#
# Generation 20 - Current best internal CV score: -5.0099385700467376e-05
#
# Generation 21 - Current best internal CV score: -5.0099385700467376e-05
#
# Generation 22 - Current best internal CV score: -4.9396441360760764e-05
#
# Generation 23 - Current best internal CV score: -4.9396441360760764e-05
#
# Generation 24 - Current best internal CV score: -4.914132705569676e-05
#
# Generation 25 - Current best internal CV score: -4.910195204539346e-05
#
# Generation 26 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 27 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 28 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 29 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 30 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 31 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 32 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 33 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 34 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 35 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 36 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 37 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 38 - Current best internal CV score: -4.8121705344716515e-05
#
# Generation 39 - Current best internal CV score: -4.8078099427684106e-05
#
# Generation 40 - Current best internal CV score: -4.8078099427684106e-05
#
# Generation 41 - Current best internal CV score: -4.785977681336303e-05
#
# Generation 42 - Current best internal CV score: -4.7745204842147636e-05
#
# Generation 43 - Current best internal CV score: -4.735438528908718e-05
#
# Generation 44 - Current best internal CV score: -4.735438528908718e-05
#
# Generation 45 - Current best internal CV score: -4.660093000511085e-05
#
# Generation 46 - Current best internal CV score: -4.660093000511085e-05
#
# Generation 47 - Current best internal CV score: -4.660093000511085e-05
#
# Generation 48 - Current best internal CV score: -4.660093000511085e-05
#
# Generation 49 - Current best internal CV score: -4.660093000511085e-05
#
# Generation 50 - Current best internal CV score: -4.660093000511085e-05
#
# Generation 51 - Current best internal CV score: -4.354943828463341e-05
#
# Generation 52 - Current best internal CV score: -4.354943828463341e-05
#
# Generation 53 - Current best internal CV score: -4.354943828463341e-05
#
# Generation 54 - Current best internal CV score: -4.30607706841154e-05
#
# Generation 55 - Current best internal CV score: -4.30607706841154e-05
#
# Generation 56 - Current best internal CV score: -4.27083240989936e-05
#
# Generation 57 - Current best internal CV score: -4.27083240989936e-05
#
# Generation 58 - Current best internal CV score: -4.27083240989936e-05
#
# Generation 59 - Current best internal CV score: -4.27083240989936e-05
#
# Generation 60 - Current best internal CV score: -4.27083240989936e-05
#
# Generation 61 - Current best internal CV score: -4.269381641503938e-05
#
# Generation 62 - Current best internal CV score: -4.269381641503938e-05
#
# Generation 63 - Current best internal CV score: -4.253019146579188e-05
#
# Generation 64 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 65 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 66 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 67 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 68 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 69 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 70 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 71 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 72 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 73 - Current best internal CV score: -4.2455674198993155e-05
#
# Generation 74 - Current best internal CV score: -4.2455674198993155e-05
#
# The optimized pipeline was not improved after evaluating 10 more generations. Will end the optimization process.
#
# TPOT closed prematurely. Will use the current best pipeline.
#
# Best pipeline: XGBRegressor(LinearSVR(RidgeCV(PolynomialFeatures(input_matrix, degree=2, include_bias=False, interaction_only=False)), C=25.0, dual=False, epsilon=0.0001, loss=squared_epsilon_insensitive, tol=0.01), learning_rate=0.1, max_depth=8, min_child_weight=18, n_estimators=100, n_jobs=1, objective=reg:squarederror, subsample=0.8500000000000001, verbosity=0)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

print(r2_score(y_test, pred))
print(mean_squared_error(y_test, pred))
print(mean_absolute_error(y_test, pred))
print(np.mean(np.abs((y_test - pred) / y_test)) * 100)
# Out:
# 0.9725315267793702
# 3.812375098790591e-05
# 0.004421909925339709
# 48.702336690973866
